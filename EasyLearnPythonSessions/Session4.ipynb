# %%
DataStr = "EmpName,DOB,ID,Design,DOJ,Team,Manager"
DataStr1 = "SurajRaj,14 Nov 1995,3457,Assistant,10th of March 2010,HR,Rakesh"

Employee_des ="""
    Vijay Chekuri born on 14 Nov 1995 is an employee with id 1234 working as a developer. He joined on 10th of March 2010. He works in Development team. His manager is Krishna.
"""

# %%
dataArray = DataStr.split(",")


dataArray1 = DataStr1.split(",")

# print(dataArray)
# print(dataArray1)
dataArray1
# Out:
# ['SurajRaj',
#  '14 Nov 1995',
#  '3457',
#  'Assistant',
#  '10th of March 2010',
#  'HR',
#  'Rakesh']

# %%
parameterized = f"""
    {dataArray1[0]} born on {dataArray1[1]}  is an employee with id 1234 working as a developer. He joined on 10th of March 2010. He works in Development team. His manager is Krishna.
"""

print(parameterized)
# Out:
#     SurajRaj born on 14 Nov 1995  is an employee with id 1234 working as a developer. He joined on 10th of March 2010. He works in Development team. His manager is Krishna.

# %%
if parameterized.find("Raj") > 0 :
    print("found Raj in the str")
# Out:
# found Raj in the str

# %%
if parameterized.find("asgwersg",) == -1:
    print("the str in not present")
# Out:
# the str in not present

# %%
if "Development" in parameterized:
    print("Development str is found")
# Out:
# Development str is found

# %%
parameterized = f"""
    {dataArray1[0]} born on {dataArray1[1]}  is an employee with id 1234 working as a developer. He joined on 10th of March 2010. He works in Development team. His manager is Krishna.
"""

print(parameterized)
# Out:
#     SurajRaj born on 14 Nov 1995  is an employee with id 1234 working as a developer. He joined on 10th of March 2010. He works in Development team. His manager is Krishna.

# %%
print(parameterized.find("Raj"))
# Out:
# 10

# %%
text = "SurajRaj born on 14 Nov 1995  is an employee with id 1234 working as a developer. He joined on 10th of March 2010. He works in Development team. His manager is Krishna."

# Find the position of 'programming'
position = text.find("Raj")
print(position)  # Output: 7
# Out:
# 5
